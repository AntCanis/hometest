# %% [markdown]
# **將存有花的資料夾在google雲端內開啟,並且安裝需要的套件**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/My Drive/app/archive.zip" /content/
! unzip /content/archive.zip > data_unzip.log

# %%
! pip install split-folders

# %% [markdown]
# 把flower資料夾設成輸入,並把輸出放到Output_Folder資料夾,並分割

# %%
import splitfolders

input_folder = "/content/flowers" #Enter Input Folder
output = "Output_Folder" #Enter Output Folder

splitfolders.ratio(input_folder, output=output, seed=42, ratio=(0.7,0.2,0.1))
# Out:
# Copying files: 4317 files [00:01, 3581.54 files/s]

# %% [markdown]
# 分出訓練集

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.2,horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/Output_Folder/train',target_size = (64, 64),batch_size = 32,class_mode = 'categorical')
# Out:
# Found 3019 images belonging to 5 classes.

# %% [markdown]
# 分出驗證集

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/Output_Folder/val',target_size = (64, 64),batch_size = 32,class_mode = 'categorical')
# Out:
# Found 860 images belonging to 5 classes.

# %% [markdown]
# 分出測試集

# %%
fianl_datagen = ImageDataGenerator(rescale = 1./255)
final_set = test_datagen.flow_from_directory('/content/Output_Folder/test',target_size = (64, 64),batch_size = 32,class_mode = 'categorical')
# Out:
# Found 438 images belonging to 5 classes.

# %% [markdown]
# 建立模型

# %%
cnn = tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
cnn.add(tf.keras.layers.Flatten())
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))
cnn.add(tf.keras.layers.Dense(units=5, activation='softmax'))

# %%
cnn.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history = cnn.fit(x = training_set, validation_data = test_set, epochs = 30)
# Out:
# Epoch 1/30
# 95/95 [==============================] - 18s 168ms/step - loss: 1.3195 - accuracy: 0.4253 - val_loss: 1.0942 - val_accuracy: 0.5465
# Epoch 2/30
# 95/95 [==============================] - 14s 145ms/step - loss: 1.1103 - accuracy: 0.5538 - val_loss: 1.0380 - val_accuracy: 0.5721
# Epoch 3/30
# 95/95 [==============================] - 14s 143ms/step - loss: 1.0132 - accuracy: 0.6081 - val_loss: 1.0124 - val_accuracy: 0.6035
# Epoch 4/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.9559 - accuracy: 0.6287 - val_loss: 1.0103 - val_accuracy: 0.5942
# Epoch 5/30
# 95/95 [==============================] - 14s 144ms/step - loss: 0.8977 - accuracy: 0.6575 - val_loss: 0.9742 - val_accuracy: 0.6140
# Epoch 6/30
# 95/95 [==============================] - 14s 144ms/step - loss: 0.8617 - accuracy: 0.6698 - val_loss: 0.8917 - val_accuracy: 0.6407
# Epoch 7/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.8141 - accuracy: 0.6857 - val_loss: 0.8699 - val_accuracy: 0.6558
# Epoch 8/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.7433 - accuracy: 0.7181 - val_loss: 0.9619 - val_accuracy: 0.6488
# Epoch 9/30
# 95/95 [==============================] - 13s 142ms/step - loss: 0.7265 - accuracy: 0.7277 - val_loss: 0.8628 - val_accuracy: 0.6535
# Epoch 10/30
# 95/95 [==============================] - 13s 142ms/step - loss: 0.6784 - accuracy: 0.7440 - val_loss: 0.8912 - val_accuracy: 0.6651
# Epoch 11/30
# 95/95 [==============================] - 13s 142ms/step - loss: 0.6551 - accuracy: 0.7446 - val_loss: 1.0035 - val_accuracy: 0.6267
# Epoch 12/30
# 95/95 [==============================] - 13s 142ms/step - loss: 0.6162 - accuracy: 0.7648 - val_loss: 0.9920 - val_accuracy: 0.6453
# Epoch 13/30
# 95/95 [==============================] - 14s 144ms/step - loss: 0.5835 - accuracy: 0.7748 - val_loss: 0.8594 - val_accuracy: 0.6779
# Epoch 14/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.5504 - accuracy: 0.7950 - val_loss: 0.9576 - val_accuracy: 0.6547
# Epoch 15/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.5127 - accuracy: 0.8069 - val_loss: 0.8705 - val_accuracy: 0.6837
# Epoch 16/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.4918 - accuracy: 0.8178 - val_loss: 0.8511 - val_accuracy: 0.6721
# Epoch 17/30
# 95/95 [==============================] - 14s 142ms/step - loss: 0.4395 - accuracy: 0.8400 - val_loss: 0.8621 - val_accuracy: 0.7058
# Epoch 18/30
# 95/95 [==============================] - 13s 142ms/step - loss: 0.4124 - accuracy: 0.8506 - val_loss: 0.9143 - val_accuracy: 0.6663
# Epoch 19/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.3845 - accuracy: 0.8566 - val_loss: 0.9493 - val_accuracy: 0.6779
# Epoch 20/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.3806 - accuracy: 0.8559 - val_loss: 0.9626 - val_accuracy: 0.6860
# Epoch 21/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.3765 - accuracy: 0.8635 - val_loss: 1.0094 - val_accuracy: 0.6593
# Epoch 22/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.3180 - accuracy: 0.8791 - val_loss: 1.1728 - val_accuracy: 0.6593
# Epoch 23/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.3359 - accuracy: 0.8784 - val_loss: 1.0166 - val_accuracy: 0.6802
# Epoch 24/30
# 95/95 [==============================] - 14s 144ms/step - loss: 0.2836 - accuracy: 0.8976 - val_loss: 1.1169 - val_accuracy: 0.6616
# Epoch 25/30
# 95/95 [==============================] - 14s 143ms/step - loss: 0.2457 - accuracy: 0.9179 - val_loss: 1.2573 - val_accuracy: 0.6756
# Epoch 26/30
# 95/95 [==============================] - 14s 144ms/step - loss: 0.2450 - accuracy: 0.9152 - val_loss: 1.2140 - val_accuracy: 0.6721
# Epoch 27/30
# 95/95 [==============================] - 13s 142ms/step - loss: 0.2268 - accuracy: 0.9238 - val_loss: 1.2617 - val_accuracy: 0.6616
# Epoch 28/30
# 95/95 [==============================] - 14s 148ms/step - loss: 0.2156 - accuracy: 0.9192 - val_loss: 1.2328 - val_accuracy: 0.6605
# Epoch 29/30
# 95/95 [==============================] - 19s 200ms/step - loss: 0.2081 - accuracy: 0.9268 - val_loss: 1.3010 - val_accuracy: 0.6581
# Epoch 30/30
# 95/95 [==============================] - 14s 144ms/step - loss: 0.1870 - accuracy: 0.9321 - val_loss: 1.2592 - val_accuracy: 0.6826

# %% [markdown]
# 輸出準確度

# %%
loss, accuracy= cnn.evaluate(final_set)
print(f'Accuracy: {accuracy*100}')
# Out:
# 14/14 [==============================] - 1s 77ms/step - loss: 1.1402 - accuracy: 0.7032
# Accuracy: 70.31963467597961

# %% [markdown]
# 抽10筆資料印出來,並顯示預測結果

# %%
from io import BytesIO
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import img_to_array
import urllib

def loadImage(URL):
    with urllib.request.urlopen(URL) as url:
        img = load_img(BytesIO(url.read()), target_size=(64, 64))

    return img_to_array(img)

# %%
import numpy as np
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
import matplotlib.pyplot as plt
import matplotlib.image as img
from skimage import io
from google.colab.patches import cv2_imshow
import random
test = ["https://shoplineimg.com/5d9d940ff12a7000017ef3dd/601e9e9e759e940c8ebd9e45/800x.webp?source_format=png%22,%22",
               "https://static.ctwant.com/images/cover/73/167673/lg-b6ea4563c1324eb94e00f65b03517f8b.jpg",
               
               
                "https://images.unsplash.com/photo-1586968295564-92fd7572718b?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxzZWFyY2h8Mnx8dHVsaXB8ZW58MHx8MHx8&w=1000&q=80",
                "data:image/jpeg;base64,...",
                "data:image/jpeg;base64,...",
                "data:image/jpeg;base64,...",
                "data:image/jpeg;base64,...",
                "data:image/jpeg;base64,..."
              ,"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRN7E8QJfhpvOJxyfoCXKiSzgUVc112vOoIhw&usqp=CAU"
              ,"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQSlXQYZ71kXxr2fjlKa5bWnt04EbHwbAc1WQtR0mOvVH1--5Yi9BvbYNAF0KSEjmgiEgM&usqp=CAU"
              ,"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSS5tJYOSSge10ySpvLIsfT8hHvvmvKgTDqmA&usqp=CAU",
              "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT1u7CtqOfqJuXpSJLy5xe0a0MopSGgb3dB0Q&usqp=CAU"
              ,"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcREK-ktNdd7RA5oCJPaqZ3YyzxZXg2_WsOrzQ&usqp=CAU"
              
              ,"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRa2juEa2GY2cM27Fw09llqm8CpMVymCEoQrQ&usqp=CAU"
              ,"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQy8kPbJ0awgVrnHBAw_mOAPfd-Y6WS6qpYgA&usqp=CAU"]
temp = random.sample(range(0,len(test)),10)  #用來隨機抽取10比資料
for i in temp:

 
  image = loadImage(test[i])
  test_image = img_to_array(image)
  test_image = np.expand_dims(test_image, axis = 0)     #去嘗試分類被抽出來測試的花

  result = cnn.predict(test_image)

  img_src = (test[i])
  cap = cv2.VideoCapture(img_src)
  if(cap.isOpened()):
    ret,img = cap.read()
    img = cv2.resize(img, (150, 150))
    cv2_imshow(img)                          #印出圖片,並把預測的名稱印在圖片下面
    cv2.waitKey()
    flower_name = ['daisy雛菊', 'dandelion蒲公英', 'rose玫瑰', 'sunflower太陽花', 'tulip鬱金香']
    for i in range(0,5):
      if result[0][i] == 1.0:
        print(flower_name[i])
# Out:
# 1/1 [==============================] - 0s 19ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC451BB28E0>
# tulip鬱金香
# 1/1 [==============================] - 0s 20ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC3B218B970>
# sunflower太陽花
# 1/1 [==============================] - 0s 21ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC451BB2F40>
# tulip鬱金香
# 1/1 [==============================] - 0s 21ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC3B2210910>
# daisy雛菊
# 1/1 [==============================] - 0s 20ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC3B2147580>
# dandelion蒲公英
# 1/1 [==============================] - 0s 24ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC3B21F3BE0>
# tulip鬱金香
# 1/1 [==============================] - 0s 20ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC3B20DC220>
# sunflower太陽花
# 1/1 [==============================] - 0s 18ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC3B22BFB50>
# tulip鬱金香
# 1/1 [==============================] - 0s 27ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC36850CBE0>
# rose玫瑰
# 1/1 [==============================] - 0s 27ms/step
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FC3B27DE460>
# daisy雛菊
